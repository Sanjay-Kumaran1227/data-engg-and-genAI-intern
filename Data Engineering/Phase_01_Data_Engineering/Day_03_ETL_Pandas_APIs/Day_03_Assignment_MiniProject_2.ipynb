# %%
import pandas as pd

print("=" * 60)
print("EMPLOYEE SALARY ETL PROJECT")
print("=" * 60)

data = {
    "employee_id": [101, 102, 103, 104, 105, 102, 106, 107],
    "employee_name": ["Arun", "Bala", "Chitra", "Divya", "Ezhil", "Bala", "Farhan", "Gokul"],
    "department": ["HR", "IT", "Finance", "IT", "Sales", "IT", "HR", "Finance"],
    "monthly_salary": [30000, 45000, 50000, 60000, 35000, 45000, 32000, 55000]
}

df = pd.DataFrame(data)

# Save raw data as Excel
df.to_excel("employee_salary_data.xlsx", index=False)

# Extract
df = pd.read_excel("employee_salary_data.xlsx")

print("\nOriginal Dataset:")
print(df)

# Transform
df = df.drop_duplicates()

df["yearly_salary"] = df["monthly_salary"] * 12

print("\nCleaned Dataset:")
print(df)

# Load
df.to_csv("cleaned_employee_salary.csv", index=False)

print("\nCleaned dataset saved as cleaned_employee_salary.csv")
# Out:
# ============================================================
# EMPLOYEE SALARY ETL PROJECT
# ============================================================
#
# Original Dataset:
#    employee_id employee_name department  monthly_salary
# 0          101          Arun         HR           30000
# 1          102          Bala         IT           45000
# 2          103        Chitra    Finance           50000
# 3          104         Divya         IT           60000
# 4          105         Ezhil      Sales           35000
# 5          102          Bala         IT           45000
# 6          106        Farhan         HR           32000
# 7          107         Gokul    Finance           55000
#
# Cleaned Dataset:
#    employee_id employee_name department  monthly_salary  yearly_salary
# 0          101          Arun         HR           30000         360000
# 1          102          Bala         IT           45000         540000
# 2          103        Chitra    Finance           50000         600000
# 3          104         Divya         IT           60000         720000
# 4          105         Ezhil      Sales           35000         420000
# 6          106        Farhan         HR           32000         384000
# 7          107         Gokul    Finance           55000         660000
#
# Cleaned dataset saved as cleaned_employee_salary.csv
